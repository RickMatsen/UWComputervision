# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dataloader_transforms import *
from matplotlib import pyplot as plt
import torch
from torchvision import transforms
from utils.xray_plot import draw_pred

# %%
imgs = torch.load("tensors_padded_updated/X_3.pt")
idx = 1
labs = torch.load("tensors_padded_updated/y_3.pt")

# %%
cur_img = imgs[idx]
cur_labs = labs[idx]

# %%
plt.figure(figsize=(5,5))
draw_pred(imgs, labs, idx);
# Out:
# tensor([117.4205, 135.2876,  45.9726, 182.4888, 189.9601])

# %%
cur_img = imgs[idx]
cur_labs = labs[idx]
aimgs, alabs = random_crop( (cur_img, cur_labs) )

# %%
plt.figure(figsize=(5,8))
draw_pred(aimgs.unsqueeze(0), alabs.unsqueeze(0), 0);
# Out:
# tensor([133.2003, 137.0032,  60.9791, 219.5084, 209.5222])

# %%
imgs.shape, aimgs.shape
# Out:
# (torch.Size([163, 3, 256, 256]), torch.Size([3, 256, 256]))

# %%
alabs
# Out:
# tensor([140.7549, 155.4385,  42.4880, 196.1349,  97.9009, 193.9980, 158.0956,
#         164.2285, 106.5002, 181.0975, 126.3454, 225.7171, 101.9040])

# %%
labs[0]
# Out:
# tensor([133.2889, 127.5062,  47.1326, 201.4278, 179.7620, 196.9673, 119.0562,
#         166.8678, 171.6467, 183.0757, 147.8303, 223.4250, 167.6768])

# %%
plt.imshow(imgs[0].permute(1,2,0).int())

# %%
plt.imshow(transforms.functional.hflip(imgs[0]).permute(1,2,0).int())

# %%
a = torch.load("X_3.pt")
a_y = torch.load("y_3.pt")
b = torch.load("../X_3.pt")
b_y = torch.load("../y_3.pt")

# %%
a_y[0], b_y[0]
# Out:
# (tensor([133.2889, 127.5062,  47.1326, 201.4278, 179.7620, 196.9673, 119.0562,
#          166.8678, 171.6467, 183.0757, 147.8303, 223.4250, 167.6768]),
#  tensor([133.2889, 127.5062,  47.1326, 201.4278, 179.7620, 196.9673, 119.0562,
#          166.8678, 171.6467, 183.0757, 147.8303, 223.4250, 167.6768]))

# %%
torch.allclose(a,b)
# Out:
# False

# %%
plt.imshow(a[0].permute(1,2,0).int())

# %%
plt.imshow(b[0].permute(1,2,0).int())

# %%
draw_pred(a, a_y, 0)
# Out:
# tensor([133.2889, 127.5062,  47.1326, 201.4278, 179.7620])
